# %% [markdown]
# <a href="https://colab.research.google.com/github/vijikumar22/Advance_Gen_AI_Feb_2026_Internship/blob/main/Logic_Building_Task_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Problem 1: Unique words in a sentence

# %%
sentence = "python is easy and python is powerful"
words = sentence.split()
unique_words = set(words)
print("Unique words count:", len(unique_words))
print("Unique words:", unique_words)
# Out:
# Unique words count: 5
# Unique words: {'easy', 'powerful', 'python', 'is', 'and'}

# %% [markdown]
# ## Problem 2: Highest salary from employee data

# %%
employees = {
    "Ravi": 75000,
    "Anita": 68000,
    "Kiran": 72000
}
highest_employee = ""
highest_salary = 0
for name, salary in employees.items():
    if salary > highest_salary:
        highest_salary = salary
        highest_employee = name

print("Highest Salary:", highest_employee, "-", highest_salary)
# Out:
# Highest Salary: Ravi - 75000

# %% [markdown]
# ## Problem 3: Find maximum and minimum values

# %%
numbers = [45, 22, 89, 10, 66]
maximum = numbers[0]
minimum = numbers[0]
for num in numbers:
    if num > maximum:
        maximum = num
    if num < minimum:
        minimum = num

print("List:", numbers)
print("Max :", maximum)
print("Min :", minimum)
# Out:
# List: [45, 22, 89, 10, 66]
# Max : 89
# Min : 10

# %% [markdown]
# ## Problem 4: Count products above price threshold

# %%
prices = [450, 1200, 899, 1500, 300]
count = 0
for price in prices:
    if price > 1000:
        count += 1

print("Products above 1000:", count)
# Out:
# Products above 1000: 2

# %% [markdown]
# ## Problem 5: Calculate attendance percentage

# %%
attendance = ["P", "P", "A", "P", "P"]
present_count = 0
for status in attendance:
    if status == "P":
        present_count += 1

percentage = (present_count / len(attendance)) * 100
print("Attendance Percentage:", percentage)
# Out:
# Attendance Percentage: 80.0

# %% [markdown]
# ## Problem 6: Remove duplicate phone numbers

# %%
phone_numbers = [9876543210, 9123456789, 9876543210]
unique_numbers = set(phone_numbers)
print("Unique phone numbers:", unique_numbers)
# Out:
# Unique phone numbers: {9876543210, 9123456789}

# %% [markdown]
# ## Problem 7: Count character frequency

# %%
text = "python"
frequency = {}
for char in text:
    if char in frequency:
        frequency[char] += 1
    else:
        frequency[char] = 1

print(frequency)
# Out:
# {'p': 1, 'y': 1, 't': 1, 'h': 1, 'o': 1, 'n': 1}

# %% [markdown]
# ## Problem 8: Convert List to Tuple

# %%
numbers = [10, 20, 30]
result = tuple(numbers)
print("Tuple:", result)
print("Type :",type(result))
# Out:
# Tuple: (10, 20, 30)
# Type : <class 'tuple'>

# %% [markdown]
# ## Problem 9: Check if key exists in dictionary

# %%
employees = {
    "Ravi": 75000,
    "Anita": 68000,
    "Vijay":80000,
    "Devraj":23221
}
if "Vijay" in employees:
    print("Employee exists")
else:
    print("Employee does not exist")
# Out:
# Employee exists

# %% [markdown]
# ## Problem 10: Calculate average marks

# %%
marks = [70, 75, 80, 65]
total = 0
for mark in marks:
    total += mark

average = total / len(marks)
print("Average Marks:", average)
# Out:
# Average Marks: 72.5
